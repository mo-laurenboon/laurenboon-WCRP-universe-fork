# %%
import requests, os, json, glob
import pandas as pd

# %%
url = 'https://raw.githubusercontent.com/WCRP-CMIP/CMIP6Plus_CVs/refs/heads/main/CMIP6Plus_source_id.json'
data = requests.get(url).json()['source_id']
data
# Out:
# {'CESM2': {'activity_participation': ['CMIP', 'RAMIP'],
#   'cohort': ['Published'],
#   'institution_id': ['NCAR'],
#   'label': 'CESM2',
#   'label_extended': 'CESM2',
#   'license_info': {'exceptions_contact': '@ucar.edu <- cesm_cmip6',
#    'history': '2019-02-18: initially published under CC BY-SA 4.0; 2022-06-16: relaxed to CC BY 4.0',
#    'id': 'CC BY 4.0',
#    'license': 'Creative Commons Attribution 4.0 International (CC BY 4.0; https://creativecommons.org/licenses/by/4.0/)',
#    'source_specific_info': '',
#    'url': 'https://creativecommons.org/licenses/by/4.0/'},
#   'model_component': {'aerosol': {'description': 'MAM4 (same grid as atmos)',
#     'native_nominal_resolution': '100 km'},
#    'atmos': {'description': 'CAM6 (0.9x1.25 finite volume grid; 288 x 192 longitude/latitude; 32 levels; top level 2.25 mb)',
#     'native_nominal_resolution': '100 km'},
#    'atmosChem': {'description': 'MAM4 (same grid as atmos)',
#     'native_nominal_resolution': '100 km'},
# ...

# %%
group = []
parents = {}
for _,i in data.items():
    
    dummy = []
    for c,d in i['model_component'].items():
        
        
        family = ''
        for f in families:
            if f['id'] in d['description'].lower():
                family = f['id']
        
        
        dummy2 = {
            "id": d['description'].split(' ')[0].split('/')[0].lower().replace('_','-').replace('.','~'),
            "type":"wcrp:model-component",
            "model-family":family,
            "component-family":'',
            "label":d['description'].split(' ')[0],
            "description": d['description'],
            "realm": c.lower(),
            "native-nominal-resolution": [d['native_nominal_resolution'].replace(' ','')],
            "native-horizontal-grid":"",
            "native-vertical-grid":"",
            "configuration":'',
            "references":[],
            "codebase":'',
            "embedded-in":'',
            "coupled-with":'',
            
        }
        
        dummy.append(dummy2)
        
        # del dummy2['native-nominal-resolution']
        
        group.append(dummy2)
    parents[_.lower()] = dummy

# %%
# for i in group:
#     json.dump(i,open(f'{i["id"]}.json','w'),indent=4)

# %%
# pd.DataFrame(group).to_csv('model_components_test.csv')

# %%
a = ''
for i in group: a+= i['description']
a
# Out:
# 'MAM4 (same grid as atmos)CAM6 (0.9x1.25 finite volume grid; 288 x 192 longitude/latitude; 32 levels; top level 2.25 mb)MAM4 (same grid as atmos)CLM5 (same grid as atmos)CISM2.1POP2 (320x384 longitude/latitude; 60 levels; top grid cell 0-10 m)MARBL (same grid as ocean)CICE5.1 (same grid as ocean)TACTIC_v2Arpege 6.3 (T127; Gaussian Reduced with 24572 grid points in total distributed over 128 latitude circles (with 256 grid points per latitude circle between 30degN and 30degS reducing to 20 grid points per latitude circle at 88.9degN and 88.9degS); 91 levels; top level 78.4 km)REPROBUS-C_v2Surfex 8.0cnoneNemo 3.6 (eORCA1, tripolar primarily 1deg; 362 x 294 longitude/latitude; 75 levels; top grid cell 0-1 m)Pisces 2.sGelato 6.1interactiveCanAM5.1 (T63L49 native atmosphere, T63 Linear Gaussian Grid; 128 x 64 longitude/latitude; 49 levels; top level 1 hPa)specified oxidants for aerosolsCLASS3.6/CTEM1.2specified ice sheetsNEMO3.4.1 (ORCA1 tripolar grid, 1 deg with refinement to 1/3 deg wit
# ...

# %%
json.dump(parents, open('dump.json','w'))
parents
# Out:
# {'cesm2': [{'id': 'mam4',
#    'type': 'wcrp:model-component',
#    'model-family': '',
#    'component-family': '',
#    'label': 'MAM4',
#    'description': 'MAM4 (same grid as atmos)',
#    'realm': 'aerosol',
#    'native-nominal-resolution': ['100km'],
#    'native-horizontal-grid': '',
#    'native-vertical-grid': '',
#    'configuration': '',
#    'references': [],
#    'codebase': '',
#    'embedded-in': '',
#    'coupled-with': ''},
#   {'id': 'cam6',
#    'type': 'wcrp:model-component',
#    'model-family': 'cam',
#    'component-family': '',
#    'label': 'CAM6',
#    'description': 'CAM6 (0.9x1.25 finite volume grid; 288 x 192 longitude/latitude; 32 levels; top level 2.25 mb)',
#    'realm': 'atmos',
#    'native-nominal-resolution': ['100km'],
#    'native-horizontal-grid': '',
#    'native-vertical-grid': '',
#    'configuration': '',
#    'references': [],
#    'codebase': '',
#    'embedded-in': '',
#    'coupled-with': ''},
#   {'id': 'mam4',
# ...

# %%
parents2 = {
  "cesm2": [
    {
      "id": "mam4",
      "type": "wcrp:model-component",
      "model-family": "",
      "component-family": "mam",
      "label": "MAM4",
      "description": "MAM4 (same grid as atmos)",
      "realm": "aerosol",
      "native-nominal-resolution": [
        "100km"
      ],
      "native-horizontal-grid": "",
      "native-vertical-grid": "",
      "configuration": "",
      "references": [],
      "codebase": "",
      "embedded-in": "",
      "coupled-with": ""
    },
    {
      "id": "cam6",
      "type": "wcrp:model-component",
      "model-family": "cam",
      "component-family": "cam",
      "label": "CAM6",
      "description": "CAM6 (0.9x1.25 finite volume grid; 288 x 192 longitude/latitude; 32 levels; top level 2.25 mb)",
      "realm": "atmos",
      "native-nominal-resolution": [
        "100km"
      ],
      "native-horizontal-grid": "288 x 192 longitude/latitude",
      "native-vertical-grid": "32 levels",
      "configuration": "",
      "references": [],
      "codebase": "",
      "embedded-in": "",
      "coupled-with": ""
    },
    {
      "id": "mam4",
      "type": "wcrp:model-component",
      "model-family": "",
      "component-family": "mam",
      "label": "MAM4",
      "description": "MAM4 (same grid as atmos)",
      "realm": "atmoschem",
      "native-nominal-resolution": [
        "100km"
      ],
      "native-horizontal-grid": "",
      "native-vertical-grid": "",
      "configuration": "",
      "references": [],
      "codebase": "",
      "embedded-in": "",
      "coupled-with": ""
    },
    {
      "id": "clm5",
      "type": "wcrp:model-component",
      "model-family": "",
      "component-family": "clm",
      "label": "CLM5",
      "description": "CLM5 (same grid as atmos)",
      "realm": "land",
      "native-nominal-resolution": [
        "100km"
      ],
      "native-horizontal-grid": "",
      "native-vertical-grid": "",
      "configuration": "",
      "references": [],
      "codebase": "",
      "embedded-in": "",
      "coupled-with": ""
    },
    {
      "id": "cism2p1",
      "type": "wcrp:model-component",
      "model-family": "",
      "component-family": "cism",
      "label": "CISM2.1",
      "description": "CISM2.1",
      "realm": "landice",
      "native-nominal-resolution": [
        "5km"
      ],
      "native-horizontal-grid": "",
      "native-vertical-grid": "",
      "configuration": "",
      "references": [],
      "codebase": "",
      "embedded-in": "",
      "coupled-with": ""
    },
    {
      "id": "pop2",
      "type": "wcrp:model-component",
      "model-family": "",
      "component-family": "pop",
      "label": "POP2",
      "description": "POP2 (320x384 longitude/latitude; 60 levels; top grid cell 0-10 m)",
      "realm": "ocean",
      "native-nominal-resolution": [
        "100km"
      ],
      "native-horizontal-grid": "320x384 longitude/latitude",
      "native-vertical-grid": "60 levels",
      "configuration": "",
      "references": [],
      "codebase": "",
      "embedded-in": "",
      "coupled-with": ""
    },
    {
      "id": "marbl",
      "type": "wcrp:model-component",
      "model-family": "",
      "component-family": "marbl",
      "label": "MARBL",
      "description": "MARBL (same grid as ocean)",
      "realm": "ocnbgchem",
      "native-nominal-resolution": [
        "100km"
      ],
      "native-horizontal-grid": "",
      "native-vertical-grid": "",
      "configuration": "",
      "references": [],
      "codebase": "",
      "embedded-in": "",
      "coupled-with": ""
    },
    {
      "id": "cice5p1",
      "type": "wcrp:model-component",
      "model-family": "",
      "component-family": "cice",
      "label": "CICE5.1",
      "description": "CICE5.1 (same grid as ocean)",
      "realm": "seaice",
      "native-nominal-resolution": [
        "100km"
      ],
      "native-horizontal-grid": "",
      "native-vertical-grid": "",
      "configuration": "",
      "references": [],
      "codebase": "",
      "embedded-in": "",
      "coupled-with": ""
    }
  ],
  "cnrm-esm2-1": [
    {
      "id": "tactic-v2",
      "type": "wcrp:model-component",
      "model-family": "",
      "component-family": "",
      "label": "TACTIC_v2",
      "description": "TACTIC_v2",
      "realm": "aerosol",
      "native-nominal-resolution": [
        "250km"
      ],
      "native-horizontal-grid": "",
      "native-vertical-grid": "",
      "configuration": "",
      "references": [],
      "codebase": "",
      "embedded-in": "",
      "coupled-with": ""
    },
    {
      "id": "arpege",
      "type": "wcrp:model-component",
      "model-family": "meteo-france",
      "component-family": "",
      "label": "Arpege",
      "description": "Arpege 6.3 (T127; Gaussian Reduced with 24572 grid points in total distributed over 128 latitude circles (with 256 grid points per latitude circle between 30degN and 30degS reducing to 20 grid points per latitude circle at 88.9degN and 88.9degS); 91 levels; top level 78.4 km)",
      "realm": "atmos",
      "native-nominal-resolution": [
        "250km"
      ],
      "native-horizontal-grid": "128 latitude circles (256 grid points per latitude circle between 30degN/S)",
      "native-vertical-grid": "91 levels",
      "configuration": "",
      "references": [],
      "codebase": "",
      "embedded-in": "",
      "coupled-with": ""
    },
    {
      "id": "reprobus-c-v2",
      "type": "wcrp:model-component",
      "model-family": "",
      "component-family": "",
      "label": "REPROBUS-C_v2",
      "description": "REPROBUS-C_v2",
      "realm": "atmoschem",
      "native-nominal-resolution": [
        "250km"
      ],
      "native-horizontal-grid": "",
      "native-vertical-grid": "",
      "configuration": "",
      "references": [],
      "codebase": "",
      "embedded-in": "",
      "coupled-with": ""
    },
    {
      "id": "surfex",
      "type": "wcrp:model-component",
      "model-family": "",
      "component-family": "",
      "label": "Surfex",
      "description": "Surfex 8.0c",
      "realm": "land",
      "native-nominal-resolution": [
        "250km"
      ],
      "native-horizontal-grid": "",
      "native-vertical-grid": "",
      "configuration": "",
      "references": [],
      "codebase": "",
      "embedded-in": "",
      "coupled-with": ""
    },
    {
      "id": "none",
      "type": "wcrp:model-component",
      "model-family": "",
      "component-family": "",
      "label": "none",
      "description": "none",
      "realm": "landice",
      "native-nominal-resolution": [
        "none"
      ],
      "native-horizontal-grid": "",
      "native-vertical-grid": "",
      "configuration": "",
      "references": [],
      "codebase": "",
      "embedded-in": "",
      "coupled-with": ""
    },
    {
      "id": "nemo",
      "type": "wcrp:model-component",
      "model-family": "",
      "component-family": "nemo",
      "label": "Nemo",
      "description": "Nemo 3.6 (eORCA1, tripolar primarily 1deg; 362 x 294 longitude/latitude; 75 levels; top grid cell 0-1 m)",
      "realm": "ocean",
      "native-nominal-resolution": [
        "100km"
      ],
      "native-horizontal-grid": "362 x 292 longitude/latitude",
      "native-vertical-grid": "75 levels",
      "configuration": "",
      "references": [],
      "codebase": "",
      "embedded-in": "",
      "coupled-with": ""
    },
    {
      "id": "pisces",
      "type": "wcrp:model-component",
      "model-family": "",
      "component-family": "",
      "label": "Pisces",
      "description": "Pisces 2.s",
      "realm": "ocnbgchem",
      "native-nominal-resolution": [
        "100km"
      ],
      "native-horizontal-grid": "",
      "native-vertical-grid": "",
      "configuration": "",
      "references": [],
      "codebase": "",
      "embedded-in": "",
      "coupled-with": ""
    },
    {
      "id": "gelato",
      "type": "wcrp:model-component",
      "model-family": "",
      "component-family": "",
      "label": "Gelato",
      "description": "Gelato 6.1",
      "realm": "seaice",
      "native-nominal-resolution": [
        "100km"
      ],
      "native-horizontal-grid": "",
      "native-vertical-grid": "",
      "configuration": "",
      "references": [],
      "codebase": "",
      "embedded-in": "",
      "coupled-with": ""
    }
  ],
  "canesm5-1": [
    {
      "id": "interactive",
      "type": "wcrp:model-component",
      "model-family": "canesm",
      "component-family": "",
      "label": "interactive",
      "description": "interactive",
      "realm": "aerosol",
      "native-nominal-resolution": [
        "500km"
      ],
      "native-horizontal-grid": "",
      "native-vertical-grid": "",
      "configuration": "",
      "references": [],
      "codebase": "",
      "embedded-in": "",
      "coupled-with": ""
    },
    {
      "id": "canam5p1",
      "type": "wcrp:model-component",
      "model-family": "canesm",
      "component-family": "",
      "label": "CanAM5.1",
      "description": "CanAM5.1 (T63L49 native atmosphere, T63 Linear Gaussian Grid; 128 x 64 longitude/latitude; 49 levels; top level 1 hPa)",
      "realm": "atmos",
      "native-nominal-resolution": [
        "500km"
      ],
      "native-horizontal-grid": "",
      "native-vertical-grid": "",
      "configuration": "",
      "references": [],
      "codebase": "",
      "embedded-in": "",
      "coupled-with": ""
    },
    {
      "id": "specified",
      "type": "wcrp:model-component",
      "model-family": "",
      "component-family": "",
      "label": "specified",
      "description": "specified oxidants for aerosols",
      "realm": "atmoschem",
      "native-nominal-resolution": [
        "500km"
      ],
      "native-horizontal-grid": "",
      "native-vertical-grid": "",
      "configuration": "",
      "references": [],
      "codebase": "",
      "embedded-in": "",
      "coupled-with": ""
    },
    {
      "id": "class3p6",
      "type": "wcrp:model-component",
      "model-family": "",
      "component-family": "",
      "label": "CLASS3.6/CTEM1.2",
      "description": "CLASS3.6/CTEM1.2",
      "realm": "land",
      "native-nominal-resolution": [
        "500km"
      ],
      "native-horizontal-grid": "",
      "native-vertical-grid": "",
      "configuration": "",
      "references": [],
      "codebase": "",
      "embedded-in": "",
      "coupled-with": ""
    },
    {
      "id": "specified",
      "type": "wcrp:model-component",
      "model-family": "",
      "component-family": "",
      "label": "specified",
      "description": "specified ice sheets",
      "realm": "landice",
      "native-nominal-resolution": [
        "500km"
      ],
      "native-horizontal-grid": "",
      "native-vertical-grid": "",
      "configuration": "",
      "references": [],
      "codebase": "",
      "embedded-in": "",
      "coupled-with": ""
    },
    {
      "id": "nemo3p4p1",
      "type": "wcrp:model-component",
      "model-family": "",
      "component-family": "nemo",
      "label": "NEMO3.4.1",
      "description": "NEMO3.4.1 (ORCA1 tripolar grid, 1 deg with refinement to 1/3 deg within 20 degrees of the equator; 361 x 290 longitude/latitude; 45 vertical levels; top grid cell 0-6.19 m)",
      "realm": "ocean",
      "native-nominal-resolution": [
        "100km"
      ],
      "native-horizontal-grid": "",
      "native-vertical-grid": "",
      "configuration": "",
      "references": [],
      "codebase": "",
      "embedded-in": "",
      "coupled-with": ""
    },
    {
      "id": "canadian",
      "type": "wcrp:model-component",
      "model-family": "cmoc",
      "component-family": "",
      "label": "Canadian",
      "description": "Canadian Model of Ocean Carbon (CMOC); NPZD ecosystem with OMIP prescribed carbonate chemistry",
      "realm": "ocnbgchem",
      "native-nominal-resolution": [
        "100km"
      ],
      "native-horizontal-grid": "",
      "native-vertical-grid": "",
      "configuration": "",
      "references": [],
      "codebase": "",
      "embedded-in": "",
      "coupled-with": ""
    },
    {
      "id": "lim2",
      "type": "wcrp:model-component",
      "model-family": "",
      "component-family": "lim",
      "label": "LIM2",
      "description": "LIM2",
      "realm": "seaice",
      "native-nominal-resolution": [
        "100km"
      ],
      "native-horizontal-grid": "",
      "native-vertical-grid": "",
      "configuration": "",
      "references": [],
      "codebase": "",
      "embedded-in": "",
      "coupled-with": ""
    }
  ],
  "ec-earth-aerchem": [
    {
      "id": "tm5",
      "type": "wcrp:model-component",
      "model-family": "ec-earth",
      "component-family": "tm5",
      "label": "TM5",
      "description": "TM5 (3 x 2 degrees; 120 x 90 longitude/latitude; 34 levels; top level: 0.1 hPa)",
      "realm": "aerosol",
      "native-nominal-resolution": [
        "250km"
      ],
      "native-horizontal-grid": "",
      "native-vertical-grid": "",
      "configuration": "TM5",
      "references": [],
      "codebase": "",
      "embedded-in": "",
      "coupled-with": ""
    },
    {
      "id": "ifs",
      "type": "wcrp:model-component",
      "model-family": "ifs",
      "component-family": "cy36r4",
      "label": "IFS",
      "description": "IFS cy36r4 (TL255, linearly reduced Gaussian grid equivalent to 512 x 256 longitude/latitude; 91 levels; top level 0.01 hPa)",
      "realm": "atmos",
      "native-nominal-resolution": [
        "100km"
      ],
      "native-horizontal-grid": "",
      "native-vertical-grid": "",
      "configuration": "",
      "references": [],
      "codebase": "",
      "embedded-in": "",
      "coupled-with": ""
    },
    {
      "id": "tm5",
      "type": "wcrp:model-component",
      "model-family": "",
      "component-family": "tm5",
      "label": "TM5",
      "description": "TM5 (3 x 2 degrees; 120 x 90 longitude/latitude; 34 levels; top level: 0.1 hPa)",
      "realm": "atmoschem",
      "native-nominal-resolution": [
        "250km"
      ],
      "native-horizontal-grid": "",
      "native-vertical-grid": "",
      "configuration": "",
      "references": [],
      "codebase": "",
      "embedded-in": "",
      "coupled-with": ""
    },
    {
      "id": "htessel",
      "type": "wcrp:model-component",
      "model-family": "ifs",
      "component-family": "",
      "label": "HTESSEL",
      "description": "HTESSEL (land surface scheme built in IFS)",
      "realm": "land",
      "native-nominal-resolution": [
        "100km"
      ],
      "native-horizontal-grid": "",
      "native-vertical-grid": "",
      "configuration": "",
      "references": [],
      "codebase": "",
      "embedded-in": "",
      "coupled-with": ""
    },
    {
      "id": "none",
      "type": "wcrp:model-component",
      "model-family": "",
      "component-family": "",
      "label": "none",
      "description": "none",
      "realm": "landice",
      "native-nominal-resolution": [
        "none"
      ],
      "native-horizontal-grid": "",
      "native-vertical-grid": "",
      "configuration": "",
      "references": [],
      "codebase": "",
      "embedded-in": "",
      "coupled-with": ""
    },
    {
      "id": "nemo3p6",
      "type": "wcrp:model-component",
      "model-family": "",
      "component-family": "",
      "label": "NEMO3.6",
      "description": "NEMO3.6 (ORCA1 tripolar primarily 1 degree with meridional refinement down to 1/3 degree in the tropics; 362 x 292 longitude/latitude; 75 levels; top grid cell 0-1 m)",
      "realm": "ocean",
      "native-nominal-resolution": [
        "100km"
      ],
      "native-horizontal-grid": "",
      "native-vertical-grid": "",
      "configuration": "",
      "references": [],
      "codebase": "",
      "embedded-in": "",
      "coupled-with": ""
    },
    {
      "id": "none",
      "type": "wcrp:model-component",
      "model-family": "",
      "component-family": "",
      "label": "none",
      "description": "none",
      "realm": "ocnbgchem",
      "native-nominal-resolution": [
        "none"
      ],
      "native-horizontal-grid": "",
      "native-vertical-grid": "",
      "configuration": "",
      "references": [],
      "codebase": "",
      "embedded-in": "",
      "coupled-with": ""
    },
    {
      "id": "lim3",
      "type": "wcrp:model-component",
      "model-family": "",
      "component-family": "",
      "label": "LIM3",
      "description": "LIM3",
      "realm": "seaice",
      "native-nominal-resolution": [
        "100km"
      ],
      "native-horizontal-grid": "",
      "native-vertical-grid": "",
      "configuration": "",
      "references": [],
      "codebase": "",
      "embedded-in": "",
      "coupled-with": ""
    }
  ],
  "ec-earth3-esm-1": [
    {
      "id": "none",
      "type": "wcrp:model-component",
      "model-family": "",
      "component-family": "",
      "label": "none",
      "description": "none",
      "realm": "aerosol",
      "native-nominal-resolution": [
        "none"
      ],
      "native-horizontal-grid": "",
      "native-vertical-grid": "",
      "configuration": "",
      "references": [],
      "codebase": "",
      "embedded-in": "",
      "coupled-with": ""
    },
    {
      "id": "ifs",
      "type": "wcrp:model-component",
      "model-family": "ifs",
      "component-family": "",
      "label": "IFS",
      "description": "IFS cy36r4 (TL255, linearly reduced Gaussian grid equivalent to 512 x 256 longitude/latitude; 91 levels; top level 0.01 hPa) and co2box v1.0 (CO2 box model; global grid)",
      "realm": "atmos",
      "native-nominal-resolution": [
        "100km"
      ],
      "native-horizontal-grid": "",
      "native-vertical-grid": "",
      "configuration": "",
      "references": [],
      "codebase": "",
      "embedded-in": "",
      "coupled-with": ""
    },
    {
      "id": "none",
      "type": "wcrp:model-component",
      "model-family": "",
      "component-family": "",
      "label": "none",
      "description": "none",
      "realm": "atmoschem",
      "native-nominal-resolution": [
        "none"
      ],
      "native-horizontal-grid": "",
      "native-vertical-grid": "",
      "configuration": "",
      "references": [],
      "codebase": "",
      "embedded-in": "",
      "coupled-with": ""
    },
    {
      "id": "htessel",
      "type": "wcrp:model-component",
      "model-family": "ifs",
      "component-family": "",
      "label": "HTESSEL",
      "description": "HTESSEL (land surface scheme built in IFS) and LPJ-GUESS v4.1.2",
      "realm": "land",
      "native-nominal-resolution": [
        "100km"
      ],
      "native-horizontal-grid": "",
      "native-vertical-grid": "",
      "configuration": "",
      "references": [],
      "codebase": "",
      "embedded-in": "",
      "coupled-with": ""
    },
    {
      "id": "pism",
      "type": "wcrp:model-component",
      "model-family": "",
      "component-family": "",
      "label": "PISM",
      "description": "PISM v1.2 (5 km x 5 km for Greenland, 31 levels)",
      "realm": "landice",
      "native-nominal-resolution": [
        "5km"
      ],
      "native-horizontal-grid": "5 km x 5 km",
      "native-vertical-grid": "31 levels",
      "configuration": "",
      "references": [],
      "codebase": "",
      "embedded-in": "",
      "coupled-with": ""
    },
    {
      "id": "nemo3p6",
      "type": "wcrp:model-component",
      "model-family": "",
      "component-family": "nemo",
      "label": "NEMO3.6",
      "description": "NEMO3.6 (ORCA1 tripolar primarily 1 degree with meridional refinement down to 1/3 degree in the tropics; 362 x 292 longitude/latitude; 75 levels; top grid cell 0-1 m) and MWE v1.0 (Melt Water Emulator; same grid as ocean for the Antarctic surroundings) ",
      "realm": "ocean",
      "native-nominal-resolution": [
        "100km"
      ],
      "native-horizontal-grid": "",
      "native-vertical-grid": "",
      "configuration": "",
      "references": [],
      "codebase": "",
      "embedded-in": "",
      "coupled-with": ""
    },
    {
      "id": "pisces",
      "type": "wcrp:model-component",
      "model-family": "",
      "component-family": "pisces",
      "label": "PISCES",
      "description": "PISCES v2 (same grid as ocean)",
      "realm": "ocnbgchem",
      "native-nominal-resolution": [
        "100km"
      ],
      "native-horizontal-grid": "",
      "native-vertical-grid": "",
      "configuration": "",
      "references": [],
      "codebase": "",
      "embedded-in": "",
      "coupled-with": ""
    },
    {
      "id": "lim3",
      "type": "wcrp:model-component",
      "model-family": "",
      "component-family": "lim",
      "label": "LIM3",
      "description": "LIM3 (same grid as ocean)",
      "realm": "seaice",
      "native-nominal-resolution": [
        "100km"
      ],
      "native-horizontal-grid": "",
      "native-vertical-grid": "",
      "configuration": "",
      "references": [],
      "codebase": "",
      "embedded-in": "",
      "coupled-with": ""
    }
  ],
  "giss-e2-1-g": [
    {
      "id": "varies",
      "type": "wcrp:model-component",
      "model-family": "",
      "component-family": "",
      "label": "Varies",
      "description": "Varies with physics-version (p==1 none, p==3 OMA, p==4 TOMAS, p==5 MATRIX)",
      "realm": "aerosol",
      "native-nominal-resolution": [
        "250km"
      ],
      "native-horizontal-grid": "",
      "native-vertical-grid": "",
      "configuration": "",
      "references": [],
      "codebase": "",
      "embedded-in": "",
      "coupled-with": ""
    },
    {
      "id": "giss-e2p1",
      "type": "wcrp:model-component",
      "model-family": "giss-e2",
      "component-family": "",
      "label": "GISS-E2.1",
      "description": "GISS-E2.1 (2.5x2 degree; 144 x 90 longitude/latitude; 40 levels; top level 0.1 hPa)",
      "realm": "atmos",
      "native-nominal-resolution": [
        "250km"
      ],
      "native-horizontal-grid": "",
      "native-vertical-grid": "",
      "configuration": "",
      "references": [],
      "codebase": "",
      "embedded-in": "",
      "coupled-with": ""
    },
    {
      "id": "varies",
      "type": "wcrp:model-component",
      "model-family": "",
      "component-family": "",
      "label": "Varies",
      "description": "Varies with physics-version (p==1 Non-interactive, p>1 GPUCCINI)",
      "realm": "atmoschem",
      "native-nominal-resolution": [
        "250km"
      ],
      "native-horizontal-grid": "",
      "native-vertical-grid": "",
      "configuration": "",
      "references": [],
      "codebase": "",
      "embedded-in": "",
      "coupled-with": ""
    },
    {
      "id": "giss",
      "type": "wcrp:model-component",
      "model-family": "",
      "component-family": "",
      "label": "GISS",
      "description": "GISS LSM",
      "realm": "land",
      "native-nominal-resolution": [
        "250km"
      ],
      "native-horizontal-grid": "",
      "native-vertical-grid": "",
      "configuration": "",
      "references": [],
      "codebase": "",
      "embedded-in": "",
      "coupled-with": ""
    },
    {
      "id": "giss",
      "type": "wcrp:model-component",
      "model-family": "",
      "component-family": "",
      "label": "GISS",
      "description": "GISS Ocean (GO1, 1 degree; 360 x 180 longitude/latitude; 40 levels; top grid cell 0-10 m)",
      "realm": "ocean",
      "native-nominal-resolution": [
        "100km"
      ],
      "native-horizontal-grid": "",
      "native-vertical-grid": "",
      "configuration": "",
      "references": [],
      "codebase": "",
      "embedded-in": "",
      "coupled-with": ""
    },
    {
      "id": "giss",
      "type": "wcrp:model-component",
      "model-family": "",
      "component-family": "",
      "label": "GISS",
      "description": "GISS SI",
      "realm": "seaice",
      "native-nominal-resolution": [
        "250km"
      ],
      "native-horizontal-grid": "",
      "native-vertical-grid": "",
      "configuration": "",
      "references": [],
      "codebase": "",
      "embedded-in": "",
      "coupled-with": ""
    }
  ],
  "hadgem3-gc31-ll": [
    {
      "id": "ukca-glomap-mode",
      "type": "wcrp:model-component",
      "model-family": "hadgem3",
      "component-family": "",
      "label": "UKCA-GLOMAP-mode",
      "description": "UKCA-GLOMAP-mode",
      "realm": "aerosol",
      "native-nominal-resolution": [
        "250km"
      ],
      "native-horizontal-grid": "",
      "native-vertical-grid": "",
      "configuration": "",
      "references": [],
      "codebase": "",
      "embedded-in": "",
      "coupled-with": ""
    },
    {
      "id": "metum-hadgem3-ga7p1",
      "type": "wcrp:model-component",
      "model-family": "hadgem3",
      "component-family": "",
      "label": "MetUM-HadGEM3-GA7.1",
      "description": "MetUM-HadGEM3-GA7.1 (N96; 192 x 144 longitude/latitude; 85 levels; top level 85 km)",
      "realm": "atmos",
      "native-nominal-resolution": [
        "250km"
      ],
      "native-horizontal-grid": "",
      "native-vertical-grid": "",
      "configuration": "",
      "references": [],
      "codebase": "",
      "embedded-in": "",
      "coupled-with": ""
    },
    {
      "id": "none",
      "type": "wcrp:model-component",
      "model-family": "",
      "component-family": "",
      "label": "none",
      "description": "none",
      "realm": "atmoschem",
      "native-nominal-resolution": [
        "none"
      ],
      "native-horizontal-grid": "",
      "native-vertical-grid": "",
      "configuration": "",
      "references": [],
      "codebase": "",
      "embedded-in": "",
      "coupled-with": ""
    },
    {
      "id": "jules-hadgem3-gl7p1",
      "type": "wcrp:model-component",
      "model-family": "hadgem3",
      "component-family": "",
      "label": "JULES-HadGEM3-GL7.1",
      "description": "JULES-HadGEM3-GL7.1",
      "realm": "land",
      "native-nominal-resolution": [
        "250km"
      ],
      "native-horizontal-grid": "",
      "native-vertical-grid": "",
      "configuration": "gl7p1",
      "references": [],
      "codebase": "",
      "embedded-in": "",
      "coupled-with": ""
    },
    {
      "id": "none",
      "type": "wcrp:model-component",
      "model-family": "",
      "component-family": "",
      "label": "none",
      "description": "none",
      "realm": "landice",
      "native-nominal-resolution": [
        "none"
      ],
      "native-horizontal-grid": "",
      "native-vertical-grid": "",
      "configuration": "",
      "references": [],
      "codebase": "",
      "embedded-in": "",
      "coupled-with": ""
    },
    {
      "id": "nemo-hadgem3-go6p0",
      "type": "wcrp:model-component",
      "model-family": "hadgem3",
      "component-family": "",
      "label": "NEMO-HadGEM3-GO6.0",
      "description": "NEMO-HadGEM3-GO6.0 (eORCA1 tripolar primarily 1 deg with meridional refinement down to 1/3 degree in the tropics; 360 x 330 longitude/latitude; 75 levels; top grid cell 0-1 m)",
      "realm": "ocean",
      "native-nominal-resolution": [
        "100km"
      ],
      "native-horizontal-grid": "",
      "native-vertical-grid": "",
      "configuration": "",
      "references": [],
      "codebase": "",
      "embedded-in": "",
      "coupled-with": ""
    },
    {
      "id": "none",
      "type": "wcrp:model-component",
      "model-family": "",
      "component-family": "",
      "label": "none",
      "description": "none",
      "realm": "ocnbgchem",
      "native-nominal-resolution": [
        "none"
      ],
      "native-horizontal-grid": "",
      "native-vertical-grid": "",
      "configuration": "",
      "references": [],
      "codebase": "",
      "embedded-in": "",
      "coupled-with": ""
    },
    {
      "id": "cice-hadgem3-gsi8",
      "type": "wcrp:model-component",
      "model-family": "hadgem3",
      "component-family": "",
      "label": "CICE-HadGEM3-GSI8",
      "description": "CICE-HadGEM3-GSI8 (eORCA1 tripolar primarily 1 deg; 360 x 330 longitude/latitude)",
      "realm": "seaice",
      "native-nominal-resolution": [
        "100km"
      ],
      "native-horizontal-grid": "",
      "native-vertical-grid": "",
      "configuration": "",
      "references": [],
      "codebase": "",
      "embedded-in": "",
      "coupled-with": ""
    }
  ],
  "miroc6": [
    {
      "id": "sprintars6p0",
      "type": "wcrp:model-component",
      "model-family": "",
      "component-family": "",
      "label": "SPRINTARS6.0",
      "description": "SPRINTARS6.0",
      "realm": "aerosol",
      "native-nominal-resolution": [
        "250km"
      ],
      "native-horizontal-grid": "",
      "native-vertical-grid": "",
      "configuration": "",
      "references": [],
      "codebase": "",
      "embedded-in": "",
      "coupled-with": ""
    },
    {
      "id": "ccsr",
      "type": "wcrp:model-component",
      "model-family": "coco",
      "component-family": "ccsr",
      "label": "CCSR",
      "description": "CCSR AGCM (T85; 256 x 128 longitude/latitude; 81 levels; top level 0.004 hPa)",
      "realm": "atmos",
      "native-nominal-resolution": [
        "250km"
      ],
      "native-horizontal-grid": "360 x 256 longitude/latitude",
      "native-vertical-grid": "63 levels",
      "configuration": "",
      "references": [],
      "codebase": "",
      "embedded-in": "",
      "coupled-with": ""
    },
    {
      "id": "matsiro6p0",
      "type": "wcrp:model-component",
      "model-family": "",
      "component-family": "matsiro",
      "label": "MATSIRO6.0",
      "description": "MATSIRO6.0",
      "realm": "land",
      "native-nominal-resolution": [
        "250km"
      ],
      "native-horizontal-grid": "",
      "native-vertical-grid": "",
      "configuration": "",
      "references": [],
      "codebase": "",
      "embedded-in": "",
      "coupled-with": ""
    },
    {
      "id": "coco4p9",
      "type": "wcrp:model-component",
      "model-family": "",
      "component-family": "coco",
      "label": "COCO4.9",
      "description": "COCO4.9 (tripolar primarily 1deg; 360 x 256 longitude/latitude; 63 levels; top grid cell 0-2 m)",
      "realm": "ocean",
      "native-nominal-resolution": [
        "100km"
      ],
      "native-horizontal-grid": "",
      "native-vertical-grid": "",
      "configuration": "",
      "references": [],
      "codebase": "",
      "embedded-in": "",
      "coupled-with": ""
    },
    {
      "id": "coco4p9",
      "type": "wcrp:model-component",
      "model-family": "",
      "component-family": "coco",
      "label": "COCO4.9",
      "description": "COCO4.9",
      "realm": "seaice",
      "native-nominal-resolution": [
        "100km"
      ],
      "native-horizontal-grid": "",
      "native-vertical-grid": "",
      "configuration": "",
      "references": [],
      "codebase": "",
      "embedded-in": "",
      "coupled-with": ""
    }
  ],
  "mpi-esm1-2-hr": [
    {
      "id": ",",
      "type": "wcrp:model-component",
      "model-family": "",
      "component-family": "",
      "label": ",",
      "description": ", prescribed MACv2-SP",
      "realm": "aerosol",
      "native-nominal-resolution": [
        "100km"
      ],
      "native-horizontal-grid": "",
      "native-vertical-grid": "",
      "configuration": "",
      "references": [],
      "codebase": "",
      "embedded-in": "",
      "coupled-with": ""
    },
    {
      "id": "echam6p3",
      "type": "wcrp:model-component",
      "model-family": "",
      "component-family": "",
      "label": "ECHAM6.3",
      "description": "ECHAM6.3 (spectral T127; 384 x 192 longitude/latitude; 95 levels; top level 0.01 hPa)",
      "realm": "atmos",
      "native-nominal-resolution": [
        "100km"
      ],
      "native-horizontal-grid": "192 x 96 longitude/latitude",
      "native-vertical-grid": "47 levels",
      "configuration": "",
      "references": [],
      "codebase": "",
      "embedded-in": "",
      "coupled-with": ""
    },
    {
      "id": "jsbach3p20",
      "type": "wcrp:model-component",
      "model-family": "",
      "component-family": "",
      "label": "JSBACH3.20",
      "description": "JSBACH3.20",
      "realm": "land",
      "native-nominal-resolution": [
        "100km"
      ],
      "native-horizontal-grid": "",
      "native-vertical-grid": "",
      "configuration": "",
      "references": [],
      "codebase": "",
      "embedded-in": "",
      "coupled-with": ""
    },
    {
      "id": "prescribed",
      "type": "wcrp:model-component",
      "model-family": "",
      "component-family": "",
      "label": "prescribed",
      "description": "prescribed",
      "realm": "landice",
      "native-nominal-resolution": [
        "none"
      ],
      "native-horizontal-grid": "",
      "native-vertical-grid": "",
      "configuration": "",
      "references": [],
      "codebase": "",
      "embedded-in": "",
      "coupled-with": ""
    },
    {
      "id": "mpiom1p63",
      "type": "wcrp:model-component",
      "model-family": "",
      "component-family": "",
      "label": "MPIOM1.63",
      "description": "MPIOM1.63 (tripolar TP04, approximately 0.4deg; 802 x 404 longitude/latitude; 40 levels; top grid cell 0-12 m)",
      "realm": "ocean",
      "native-nominal-resolution": [
        "50km"
      ],
      "native-horizontal-grid": "",
      "native-vertical-grid": "",
      "configuration": "",
      "references": [],
      "codebase": "",
      "embedded-in": "",
      "coupled-with": ""
    },
    {
      "id": "hamocc6",
      "type": "wcrp:model-component",
      "model-family": "",
      "component-family": "",
      "label": "HAMOCC6",
      "description": "HAMOCC6",
      "realm": "ocnbgchem",
      "native-nominal-resolution": [
        "50km"
      ],
      "native-horizontal-grid": "",
      "native-vertical-grid": "",
      "configuration": "",
      "references": [],
      "codebase": "",
      "embedded-in": "",
      "coupled-with": ""
    },
    {
      "id": "unnamed",
      "type": "wcrp:model-component",
      "model-family": "",
      "component-family": "",
      "label": "unnamed",
      "description": "unnamed (thermodynamic (Semtner zero-layer) dynamic (Hibler 79) sea ice model)",
      "realm": "seaice",
      "native-nominal-resolution": [
        "50km"
      ],
      "native-horizontal-grid": "",
      "native-vertical-grid": "",
      "configuration": "",
      "references": [],
      "codebase": "",
      "embedded-in": "",
      "coupled-with": ""
    }
  ],
  "mpi-esm1-2-lr": [
    {
      "id": ",",
      "type": "wcrp:model-component",
      "model-family": "",
      "component-family": "",
      "label": ",",
      "description": ", prescribed MACv2-SP",
      "realm": "aerosol",
      "native-nominal-resolution": [
        "250km"
      ],
      "native-horizontal-grid": "",
      "native-vertical-grid": "",
      "configuration": "",
      "references": [],
      "codebase": "",
      "embedded-in": "",
      "coupled-with": ""
    },
    {
      "id": "echam6p3",
      "type": "wcrp:model-component",
      "model-family": "",
      "component-family": "",
      "label": "ECHAM6.3",
      "description": "ECHAM6.3 (spectral T63; 192 x 96 longitude/latitude; 47 levels; top level 0.01 hPa)",
      "realm": "atmos",
      "native-nominal-resolution": [
        "250km"
      ],
      "native-horizontal-grid": "192 x 96 longitude/latitude",
      "native-vertical-grid": "47 levels",
      "configuration": "",
      "references": [],
      "codebase": "",
      "embedded-in": "",
      "coupled-with": ""
    },
    {
      "id": "jsbach3p20",
      "type": "wcrp:model-component",
      "model-family": "",
      "component-family": "",
      "label": "JSBACH3.20",
      "description": "JSBACH3.20",
      "realm": "land",
      "native-nominal-resolution": [
        "250km"
      ],
      "native-horizontal-grid": "",
      "native-vertical-grid": "",
      "configuration": "",
      "references": [],
      "codebase": "",
      "embedded-in": "",
      "coupled-with": ""
    },
    {
      "id": "prescribed",
      "type": "wcrp:model-component",
      "model-family": "",
      "component-family": "",
      "label": "prescribed",
      "description": "prescribed",
      "realm": "landice",
      "native-nominal-resolution": [
        "none"
      ],
      "native-horizontal-grid": "",
      "native-vertical-grid": "",
      "configuration": "",
      "references": [],
      "codebase": "",
      "embedded-in": "",
      "coupled-with": ""
    },
    {
      "id": "mpiom1p63",
      "type": "wcrp:model-component",
      "model-family": "",
      "component-family": "",
      "label": "MPIOM1.63",
      "description": "MPIOM1.63 (bipolar GR1.5, approximately 1.5deg; 256 x 220 longitude/latitude; 40 levels; top grid cell 0-12 m)",
      "realm": "ocean",
      "native-nominal-resolution": [
        "250km"
      ],
      "native-horizontal-grid": "",
      "native-vertical-grid": "",
      "configuration": "",
      "references": [],
      "codebase": "",
      "embedded-in": "",
      "coupled-with": ""
    },
    {
      "id": "hamocc6",
      "type": "wcrp:model-component",
      "model-family": "",
      "component-family": "",
      "label": "HAMOCC6",
      "description": "HAMOCC6",
      "realm": "ocnbgchem",
      "native-nominal-resolution": [
        "250km"
      ],
      "native-horizontal-grid": "",
      "native-vertical-grid": "",
      "configuration": "",
      "references": [],
      "codebase": "",
      "embedded-in": "",
      "coupled-with": ""
    },
    {
      "id": "unnamed",
      "type": "wcrp:model-component",
      "model-family": "",
      "component-family": "",
      "label": "unnamed",
      "description": "unnamed (thermodynamic (Semtner zero-layer) dynamic (Hibler 79) sea ice model)",
      "realm": "seaice",
      "native-nominal-resolution": [
        "250km"
      ],
      "native-horizontal-grid": "",
      "native-vertical-grid": "",
      "configuration": "",
      "references": [],
      "codebase": "",
      "embedded-in": "",
      "coupled-with": ""
    }
  ],
  "mri-esm2-0": [
    {
      "id": "masingar",
      "type": "wcrp:model-component",
      "model-family": "",
      "component-family": "",
      "label": "MASINGAR",
      "description": "MASINGAR mk2r4 (TL95; 192 x 96 longitude/latitude; 80 levels; top level 0.01 hPa)",
      "realm": "aerosol",
      "native-nominal-resolution": [
        "250km"
      ],
      "native-horizontal-grid": "",
      "native-vertical-grid": "",
      "configuration": "",
      "references": [],
      "codebase": "",
      "embedded-in": "",
      "coupled-with": ""
    },
    {
      "id": "mri-agcm3p5",
      "type": "wcrp:model-component",
      "model-family": "",
      "component-family": "",
      "label": "MRI-AGCM3.5",
      "description": "MRI-AGCM3.5 (TL159; 320 x 160 longitude/latitude; 80 levels; top level 0.01 hPa)",
      "realm": "atmos",
      "native-nominal-resolution": [
        "100km"
      ],
      "native-horizontal-grid": "",
      "native-vertical-grid": "",
      "configuration": "",
      "references": [],
      "codebase": "",
      "embedded-in": "",
      "coupled-with": ""
    },
    {
      "id": "mri-ccm2p1",
      "type": "wcrp:model-component",
      "model-family": "",
      "component-family": "",
      "label": "MRI-CCM2.1",
      "description": "MRI-CCM2.1 (T42; 128 x 64 longitude/latitude; 80 levels; top level 0.01 hPa)",
      "realm": "atmoschem",
      "native-nominal-resolution": [
        "250km"
      ],
      "native-horizontal-grid": "",
      "native-vertical-grid": "",
      "configuration": "",
      "references": [],
      "codebase": "",
      "embedded-in": "",
      "coupled-with": ""
    },
    {
      "id": "hal",
      "type": "wcrp:model-component",
      "model-family": "",
      "component-family": "",
      "label": "HAL",
      "description": "HAL 1.0",
      "realm": "land",
      "native-nominal-resolution": [
        "100km"
      ],
      "native-horizontal-grid": "",
      "native-vertical-grid": "",
      "configuration": "",
      "references": [],
      "codebase": "",
      "embedded-in": "",
      "coupled-with": ""
    },
    {
      "id": "none",
      "type": "wcrp:model-component",
      "model-family": "",
      "component-family": "",
      "label": "none",
      "description": "none",
      "realm": "landice",
      "native-nominal-resolution": [
        "none"
      ],
      "native-horizontal-grid": "",
      "native-vertical-grid": "",
      "configuration": "",
      "references": [],
      "codebase": "",
      "embedded-in": "",
      "coupled-with": ""
    },
    {
      "id": "mripcom4p4",
      "type": "wcrp:model-component",
      "model-family": "",
      "component-family": "",
      "label": "MRI.COM4.4",
      "description": "MRI.COM4.4 (tripolar primarily 0.5 deg latitude/1 deg longitude with meridional refinement down to 0.3 deg within 10 degrees north and south of the equator; 360 x 364 longitude/latitude; 61 levels; top grid cell 0-2 m)",
      "realm": "ocean",
      "native-nominal-resolution": [
        "100km"
      ],
      "native-horizontal-grid": "",
      "native-vertical-grid": "",
      "configuration": "",
      "references": [],
      "codebase": "",
      "embedded-in": "",
      "coupled-with": ""
    },
    {
      "id": "mripcom4p4",
      "type": "wcrp:model-component",
      "model-family": "",
      "component-family": "",
      "label": "MRI.COM4.4",
      "description": "MRI.COM4.4",
      "realm": "ocnbgchem",
      "native-nominal-resolution": [
        "100km"
      ],
      "native-horizontal-grid": "",
      "native-vertical-grid": "",
      "configuration": "",
      "references": [],
      "codebase": "",
      "embedded-in": "",
      "coupled-with": ""
    },
    {
      "id": "mripcom4p4",
      "type": "wcrp:model-component",
      "model-family": "",
      "component-family": "",
      "label": "MRI.COM4.4",
      "description": "MRI.COM4.4",
      "realm": "seaice",
      "native-nominal-resolution": [
        "100km"
      ],
      "native-horizontal-grid": "",
      "native-vertical-grid": "",
      "configuration": "",
      "references": [],
      "codebase": "",
      "embedded-in": "",
      "coupled-with": ""
    }
  ],
  "noresm2-lm": [
    {
      "id": "osloaero",
      "type": "wcrp:model-component",
      "model-family": "",
      "component-family": "",
      "label": "OsloAero",
      "description": "OsloAero",
      "realm": "aerosol",
      "native-nominal-resolution": [
        "250km"
      ],
      "native-horizontal-grid": "",
      "native-vertical-grid": "",
      "configuration": "",
      "references": [],
      "codebase": "",
      "embedded-in": "",
      "coupled-with": ""
    },
    {
      "id": "cam-oslo",
      "type": "wcrp:model-component",
      "model-family": "cam",
      "component-family": "",
      "label": "CAM-OSLO",
      "description": "CAM-OSLO (2 degree resolution; 144 x 96; 32 levels; top level 3 mb)",
      "realm": "atmos",
      "native-nominal-resolution": [
        "250km"
      ],
      "native-horizontal-grid": "144 x 96 longitude/latitude",
      "native-vertical-grid": "32 levels",
      "configuration": "",
      "references": [],
      "codebase": "",
      "embedded-in": "",
      "coupled-with": ""
    },
    {
      "id": "oslochemsimp",
      "type": "wcrp:model-component",
      "model-family": "",
      "component-family": "",
      "label": "OsloChemSimp",
      "description": "OsloChemSimp",
      "realm": "atmoschem",
      "native-nominal-resolution": [
        "250km"
      ],
      "native-horizontal-grid": "",
      "native-vertical-grid": "",
      "configuration": "",
      "references": [],
      "codebase": "",
      "embedded-in": "",
      "coupled-with": ""
    },
    {
      "id": "clm",
      "type": "wcrp:model-component",
      "model-family": "",
      "component-family": "",
      "label": "CLM",
      "description": "CLM",
      "realm": "land",
      "native-nominal-resolution": [
        "250km"
      ],
      "native-horizontal-grid": "",
      "native-vertical-grid": "",
      "configuration": "",
      "references": [],
      "codebase": "",
      "embedded-in": "",
      "coupled-with": ""
    },
    {
      "id": "cism",
      "type": "wcrp:model-component",
      "model-family": "",
      "component-family": "",
      "label": "CISM",
      "description": "CISM",
      "realm": "landice",
      "native-nominal-resolution": [
        "250km"
      ],
      "native-horizontal-grid": "",
      "native-vertical-grid": "",
      "configuration": "",
      "references": [],
      "codebase": "",
      "embedded-in": "",
      "coupled-with": ""
    },
    {
      "id": "micom",
      "type": "wcrp:model-component",
      "model-family": "",
      "component-family": "",
      "label": "MICOM",
      "description": "MICOM (1 degree resolution; 360 x 384; 70 levels; top grid cell minimum 0-2.5 m [native model uses hybrid density and generic upper-layer coordinate interpolated to z-level for contributed data])",
      "realm": "ocean",
      "native-nominal-resolution": [
        "100km"
      ],
      "native-horizontal-grid": "360 x 384 longitude/latitude",
      "native-vertical-grid": "70 levels",
      "configuration": "",
      "references": [],
      "codebase": "",
      "embedded-in": "",
      "coupled-with": ""
    },
    {
      "id": "hamocc",
      "type": "wcrp:model-component",
      "model-family": "",
      "component-family": "",
      "label": "HAMOCC",
      "description": "HAMOCC",
      "realm": "ocnbgchem",
      "native-nominal-resolution": [
        "100km"
      ],
      "native-horizontal-grid": "",
      "native-vertical-grid": "",
      "configuration": "",
      "references": [],
      "codebase": "",
      "embedded-in": "",
      "coupled-with": ""
    },
    {
      "id": "cice",
      "type": "wcrp:model-component",
      "model-family": "hadgem3",
      "component-family": "",
      "label": "CICE",
      "description": "CICE",
      "realm": "seaice",
      "native-nominal-resolution": [
        "100km"
      ],
      "native-horizontal-grid": "360 x 330 longitude/latitude",
      "native-vertical-grid": "",
      "configuration": "",
      "references": [],
      "codebase": "",
      "embedded-in": "",
      "coupled-with": ""
    }
  ],
  "ukesm1-0-ll": [
    {
      "id": "ukca-glomap-mode",
      "type": "wcrp:model-component",
      "model-family": "",
      "component-family": "",
      "label": "UKCA-GLOMAP-mode",
      "description": "UKCA-GLOMAP-mode",
      "realm": "aerosol",
      "native-nominal-resolution": [
        "250km"
      ],
      "native-horizontal-grid": "",
      "native-vertical-grid": "",
      "configuration": "",
      "references": [],
      "codebase": "",
      "embedded-in": "",
      "coupled-with": ""
    },
    {
      "id": "metum-hadgem3-ga7p1",
      "type": "wcrp:model-component",
      "model-family": "hadgem3",
      "component-family": "",
      "label": "MetUM-HadGEM3-GA7.1",
      "description": "MetUM-HadGEM3-GA7.1 (N96; 192 x 144 longitude/latitude; 85 levels; top level 85 km)",
      "realm": "atmos",
      "native-nominal-resolution": [
        "250km"
      ],
      "native-horizontal-grid": "",
      "native-vertical-grid": "",
      "configuration": "",
      "references": [],
      "codebase": "",
      "embedded-in": "",
      "coupled-with": ""
    },
    {
      "id": "ukca-strattrop",
      "type": "wcrp:model-component",
      "model-family": "",
      "component-family": "",
      "label": "UKCA-StratTrop",
      "description": "UKCA-StratTrop",
      "realm": "atmoschem",
      "native-nominal-resolution": [
        "250km"
      ],
      "native-horizontal-grid": "",
      "native-vertical-grid": "",
      "configuration": "",
      "references": [],
      "codebase": "",
      "embedded-in": "",
      "coupled-with": ""
    },
    {
      "id": "jules-es-1p0",
      "type": "wcrp:model-component",
      "model-family": "",
      "component-family": "",
      "label": "JULES-ES-1.0",
      "description": "JULES-ES-1.0",
      "realm": "land",
      "native-nominal-resolution": [
        "250km"
      ],
      "native-horizontal-grid": "",
      "native-vertical-grid": "",
      "configuration": "",
      "references": [],
      "codebase": "",
      "embedded-in": "",
      "coupled-with": ""
    },
    {
      "id": "none",
      "type": "wcrp:model-component",
      "model-family": "",
      "component-family": "",
      "label": "none",
      "description": "none",
      "realm": "landice",
      "native-nominal-resolution": [
        "none"
      ],
      "native-horizontal-grid": "",
      "native-vertical-grid": "",
      "configuration": "",
      "references": [],
      "codebase": "",
      "embedded-in": "",
      "coupled-with": ""
    },
    {
      "id": "nemo-hadgem3-go6p0",
      "type": "wcrp:model-component",
      "model-family": "hadgem3",
      "component-family": "",
      "label": "NEMO-HadGEM3-GO6.0",
      "description": "NEMO-HadGEM3-GO6.0 (eORCA1 tripolar primarily 1 deg with meridional refinement down to 1/3 degree in the tropics; 360 x 330 longitude/latitude; 75 levels; top grid cell 0-1 m)",
      "realm": "ocean",
      "native-nominal-resolution": [
        "100km"
      ],
      "native-horizontal-grid": "",
      "native-vertical-grid": "",
      "configuration": "",
      "references": [],
      "codebase": "",
      "embedded-in": "",
      "coupled-with": ""
    },
    {
      "id": "medusa2",
      "type": "wcrp:model-component",
      "model-family": "",
      "component-family": "medusa",
      "label": "MEDUSA2",
      "description": "MEDUSA2",
      "realm": "ocnbgchem",
      "native-nominal-resolution": [
        "100km"
      ],
      "native-horizontal-grid": "",
      "native-vertical-grid": "",
      "configuration": "",
      "references": [],
      "codebase": "",
      "embedded-in": "",
      "coupled-with": ""
    },
    {
      "id": "cice-hadgem3-gsi8",
      "type": "wcrp:model-component",
      "model-family": "hadgem3",
      "component-family": "",
      "label": "CICE-HadGEM3-GSI8",
      "description": "CICE-HadGEM3-GSI8 (eORCA1 tripolar primarily 1 deg; 360 x 330 longitude/latitude)",
      "realm": "seaice",
      "native-nominal-resolution": [
        "100km"
      ],
      "native-horizontal-grid": "",
      "native-vertical-grid": "",
      "configuration": "",
      "references": [],
      "codebase": "",
      "embedded-in": "",
      "coupled-with": ""
    }
  ]
}

# %%
empty = {
      "id": "",
      "type": "wcrp:model-component",
      "model-family": "",
      "component-family": "",
      "label": "",
      "description": "",
      "realm": "",
      "native-nominal-resolution": [],
      "native-horizontal-grid": "",
      "native-vertical-grid": "",
      "configuration": "",
      "references": [],
      "codebase": "",
      "embedded-in": "",
      "coupled-with": ""
    },

# %%
for file_path in glob.glob('../../../CMIP6Plus_CVs/src-data/source/*.json'):
    with open(file_path, 'r') as file:
        json_data = json.load(file)
        # print(json_data['model_component'])
        name = os.path.basename(file_path).split('.')[0]
        
        try:
            json_data['model_component'] = [i for i in parents2[name] if i['id']!='none']
        except:
            json_data['model_component'] = empty
            print(name)
            
    json.dump(json_data,open(file_path,'w'),indent=4)

# %%
parents2.keys()
# Out:
# dict_keys(['cesm2', 'cnrm-esm2-1', 'canesm5-1', 'ec-earth3-aerchem', 'ec-earth3-esm-1', 'giss-e2-1-g', 'hadgem3-gc31-ll', 'miroc6', 'mpi-esm1-2-hr', 'mpi-esm1-2-lr', 'mri-esm2-0', 'noresm2-lm', 'ukesm1-0-ll'])
